# %% [markdown]
# <center> <h2> Assignment # 2 </h2> </center>
# <center> <h3> Perform the basic wrangling on the data <h3> </center>
#
# <a href="https://colab.research.google.com/drive/1UEWivfljZ4VeSxENtEJWxd2DjaXLwwYJ#scrollTo=FYVZ5R_IXc5K"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>

# %% [markdown]
# ### Task 1: Importing Files and Libraries
# **i. Import Required libraries and Data File**

# %%
#write code here
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set()

# %% [markdown]
# **ii. Read Fifa.csv file**

# %%
#write code here
 
fifa=pd.read_csv('fifa.csv')

# %% [markdown]
# **iii. Copy dataframe in df**

# %%
#write code here

df=fifa.copy()

# %% [markdown]
# ### Task 2: Some Basic Operations on Data Frame </h3>

# %% [markdown]
# **i. Display the first five rows of the dataframe**

# %%
#Write Your Code Here

df.head()
# Out:
#        id                    name  rating position  height   foot  rare  pace  \
# 0    1001            Gábor Király      69       GK     191  Right     0   NaN
# 1  100143            Frederik Boi      65        M     184  Right     0  61.0
# 2  100264         Tomasz Szewczuk      57        A     185  Right     0  65.0
# 3  100325  Steeve Joseph-Reinette      63        D     180   Left     0  68.0
# 4  100326            Kamel Chafni      72        M     181  Right     0  75.0
#
#    shooting  passing  dribbling  defending  heading  diving  handling  \
# 0       NaN      NaN        NaN        NaN      NaN    70.0      66.0
# 1      65.0     63.0       59.0       62.0     62.0     NaN       NaN
# 2      54.0     43.0       53.0       55.0     74.0     NaN       NaN
# 3      38.0     51.0       46.0       64.0     71.0     NaN       NaN
# 4      64.0     67.0       72.0       57.0     66.0     NaN       NaN
#
#    kicking  reflexes  speed  positioning
# ...

# %% [markdown]
# **ii. Display columns names of the dataframe**

# %%
#Write Your Code Here

df.columns
# Out:
# Index(['id', 'name', 'rating', 'position', 'height', 'foot', 'rare', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'heading', 'diving',
#        'handling', 'kicking', 'reflexes', 'speed', 'positioning'],
#       dtype='object')

# %% [markdown]
# **iii. Remove extra space in column names**

# %%
#Write Your Code Here
df.columns.str.replace(' ', '')
# Out:
# Index(['id', 'name', 'rating', 'position', 'height', 'foot', 'rare', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'heading', 'diving',
#        'handling', 'kicking', 'reflexes', 'speed', 'positioning'],
#       dtype='object')

# %% [markdown]
# **iv. Check data type of columns**

# %%
#Write Your Code Here

df.dtypes
# Out:
# id               int64
# name            object
# rating           int64
# position        object
# height           int64
# foot            object
# rare             int64
# pace           float64
# shooting       float64
# passing        float64
# dribbling      float64
# defending      float64
# heading        float64
# diving         float64
# handling       float64
# kicking        float64
# reflexes       float64
# speed          float64
# positioning    float64
# dtype: object

# %% [markdown]
# **v. Get the Last five rows of dataframe**

# %%
#Write Your Code Here

df.tail()
# Out:
#         id             name  rating position  height   foot  rare  pace  \
# 8842  9801  Danijel Ljuboja      73        A     189   Left     1  62.0
# 8843  9805    Craig Bellamy      79        A     175  Right     0  80.0
# 8844  9807    Michel Breuer      68        D     183  Right     0  61.0
# 8845  9815      Gill Swerts      65        D     179  Right     0  65.0
# 8846  9913      Mehdi Nafti      69        M     179  Right     0  55.0
#
#       shooting  passing  dribbling  defending  heading  diving  handling  \
# 8842      73.0     64.0       74.0       56.0     68.0     NaN       NaN
# 8843      78.0     67.0       81.0       62.0     71.0     NaN       NaN
# 8844      40.0     56.0       51.0       70.0     74.0     NaN       NaN
# 8845      48.0     63.0       65.0       67.0     69.0     NaN       NaN
# 8846      56.0     64.0       65.0       69.0     60.0     NaN       NaN
#
#       kicking  reflexes  speed  positioning
# 8842      NaN       NaN    NaN          NaN
# ...

# %% [markdown]
# ### Question: What do you understand by having a look at the top five and last 5 rows of data?

# %% [markdown]
# *Hint: Some values are not filled for certain types of positions.*

# %% [markdown]
# ### Answer: We can observe that there are a few empty cells in columns diving, handling, kicking, reflexes, speed which are required to be filled for performing calculations. Otherwise we may not be able to perform accurate calculations.

# %% [markdown]
# ### Answer:

# %% [markdown]
# **vi. Get the statistical summary for the numerical columns**

# %%
#Write Your Code Here

#df.describe(include=['int', 'float']) 

df.describe(include=[np.number])
# Out:
#                   id       rating       height         rare         pace  \
# count    8847.000000  8847.000000  8847.000000  8847.000000  7917.000000
# mean   152337.538035    66.680457   181.750424     0.353114    67.934066
# std     54506.606056     7.146679     6.454356     0.477965    11.169316
# min         2.000000    40.000000   158.000000     0.000000    24.000000
# 25%    140001.500000    62.000000   178.000000     0.000000    62.000000
# 50%    171578.000000    66.000000   182.000000     0.000000    69.000000
# 75%    189185.000000    72.000000   186.000000     1.000000    75.000000
# max    205583.000000    94.000000   208.000000     1.000000    96.000000
#
#           shooting      passing    dribbling    defending      heading  \
# count  7917.000000  7917.000000  7917.000000  7917.000000  7917.000000
# mean     55.054440    58.845522    61.193887    60.339523    63.743337
# std      13.136116    10.962049    12.255261    10.622997     8.982680
# ...

# %% [markdown]
# :**vii. Show the statistical summary of object type columns in dataframe**

# %%
#Write Your Code Here

df.describe(include=['O'])
# Out:
#             name position   foot
# count       8847     8847   8847
# unique      8678        4      2
# top     Henrique        M  Right
# freq           5     3041   6762

# %% [markdown]
# **viii. Show the statistical summary of all the columns in dataframe**

# %%
#Write Your Code Here

df.describe(include='all')
# Out:
#                    id      name       rating position       height   foot  \
# count     8847.000000      8847  8847.000000     8847  8847.000000   8847
# unique            NaN      8678          NaN        4          NaN      2
# top               NaN  Henrique          NaN        M          NaN  Right
# freq              NaN         5          NaN     3041          NaN   6762
# mean    152337.538035       NaN    66.680457      NaN   181.750424    NaN
# std      54506.606056       NaN     7.146679      NaN     6.454356    NaN
# min          2.000000       NaN    40.000000      NaN   158.000000    NaN
# 25%     140001.500000       NaN    62.000000      NaN   178.000000    NaN
# 50%     171578.000000       NaN    66.000000      NaN   182.000000    NaN
# 75%     189185.000000       NaN    72.000000      NaN   186.000000    NaN
# max     205583.000000       NaN    94.000000      NaN   208.000000    NaN
#
#                rare         pace     shooting      passing    dribbling  \
# ...

# %% [markdown]
# ### Task 3: Dealing with Missing Value

# %% [markdown]
# :**i. Count the number of missing values in each column**

# %%
#Write Your Code Here

#df.isna().sum()

df.isnull().sum()
# Out:
# id                0
# name              0
# rating            0
# position          0
# height            0
# foot              0
# rare              0
# pace            930
# shooting        930
# passing         930
# dribbling       930
# defending       930
# heading         930
# diving         7917
# handling       7917
# kicking        7917
# reflexes       7917
# speed          7917
# positioning    7917
# dtype: int64

# %% [markdown]
# **ii. Replace extra space with NaN**

# %%
#write code here


df = df.replace(' ', np.nan, regex=True)

#df.replace(r'^\s+$', np.nan, regex=True, inplace=True)

df
# Out:
#           id name  rating position  height   foot  rare  pace  shooting  \
# 0       1001  NaN      69       GK     191  Right     0   NaN       NaN
# 1     100143  NaN      65        M     184  Right     0  61.0      65.0
# 2     100264  NaN      57        A     185  Right     0  65.0      54.0
# 3     100325  NaN      63        D     180   Left     0  68.0      38.0
# 4     100326  NaN      72        M     181  Right     0  75.0      64.0
# ...      ...  ...     ...      ...     ...    ...   ...   ...       ...
# 8842    9801  NaN      73        A     189   Left     1  62.0      73.0
# 8843    9805  NaN      79        A     175  Right     0  80.0      78.0
# 8844    9807  NaN      68        D     183  Right     0  61.0      40.0
# 8845    9815  NaN      65        D     179  Right     0  65.0      48.0
# 8846    9913  NaN      69        M     179  Right     0  55.0      56.0
#
#       passing  dribbling  defending  heading  diving  handling  kicking  \
# ...

# %% [markdown]
# **iii. Fill all null values of dataframe with 0**

# %%
#write code here

#df=fillna(0, inplace=True)

#inplace=True used to make the changes in the data frame permanent

df=df.replace(np.nan,0)

# %%
#write code here
df
# Out:
#           id name  rating position  height   foot  rare  pace  shooting  \
# 0       1001    0      69       GK     191  Right     0   0.0       0.0
# 1     100143    0      65        M     184  Right     0  61.0      65.0
# 2     100264    0      57        A     185  Right     0  65.0      54.0
# 3     100325    0      63        D     180   Left     0  68.0      38.0
# 4     100326    0      72        M     181  Right     0  75.0      64.0
# ...      ...  ...     ...      ...     ...    ...   ...   ...       ...
# 8842    9801    0      73        A     189   Left     1  62.0      73.0
# 8843    9805    0      79        A     175  Right     0  80.0      78.0
# 8844    9807    0      68        D     183  Right     0  61.0      40.0
# 8845    9815    0      65        D     179  Right     0  65.0      48.0
# 8846    9913    0      69        M     179  Right     0  55.0      56.0
#
#       passing  dribbling  defending  heading  diving  handling  kicking  \
# ...

# %% [markdown]
# **iv. Count the number of players in each position**

# %%
#Write Your Code Here

#df.groupby("position")["id"].count()

df['position'].value_counts()
# Out:
# M     3041
# D     2794
# A     2082
# GK     930
# Name: position, dtype: int64

# %% [markdown]
# **v. Check datatypes of all columns**

# %%
#write code here

df.dtypes
# Out:
# id               int64
# name            object
# rating           int64
# position        object
# height           int64
# foot            object
# rare             int64
# pace           float64
# shooting       float64
# passing        float64
# dribbling      float64
# defending      float64
# heading        float64
# diving         float64
# handling       float64
# kicking        float64
# reflexes       float64
# speed          float64
# positioning    float64
# dtype: object

# %% [markdown]
# **vi. Cast ' pace', ' shooting', ' passing', ' dribbling', ' defending',' heading', ' diving', ' handling', ' kicking', ' reflexes', ' speed',' positioning' into Integer type**

# %%
#write code here

#df['pace'] = df['pace'].astype(int)

df[['pace', 'shooting', 'passing', 'dribbling', 'defending','heading', 'diving', 'handling', 'kicking', 'reflexes', 'speed','positioning']] = df[['pace', 'shooting', 'passing', 'dribbling', 'defending','heading', 'diving', 'handling', 'kicking', 'reflexes', 'speed','positioning']].astype(int)

#df = df.astype({"pace":int,"shooting":int, "passing":int, "dribbling":int, "defending":int,"heading":int, "diving":int, "handling":int, "kicking":int, "reflexes":int, "speed":int,"positioning":int})

# %%
#write code here
df.dtypes
# Out:
# id              int64
# name           object
# rating          int64
# position       object
# height          int64
# foot           object
# rare            int64
# pace            int64
# shooting        int64
# passing         int64
# dribbling       int64
# defending       int64
# heading         int64
# diving          int64
# handling        int64
# kicking         int64
# reflexes        int64
# speed           int64
# positioning     int64
# dtype: object

# %% [markdown]
# ### Task 4

# %% [markdown]
# **You have to split the dataframe into two dataframes, one containing all the features of Goal Keeper and other dataframe contains all other players**
#
#
# ```
# # This is formatted as code
# ```

# %%
#Checking unique values in position column

df['position'].unique()
# Out:
# array(['GK', 'M', 'A', 'D'], dtype=object)

# %%
df_goalkeeper= df[df['position'] == 'GK']
df_goalkeeper

#df_others= df[df['position'] == 'M' & df['position'] == 'A']
#df_others
# Out:
#           id   name  rating position  height   foot  rare  pace  shooting  \
# 0       1001      0      69       GK     191  Right     0     0         0
# 20    100745      0      64       GK     193  Right     1     0         0
# 29    100807      0      65       GK     190  Right     0     0         0
# 31    100899      0      61       GK     185  Right     1     0         0
# 39    101282      0      70       GK     188  Right     0     0         0
# ...      ...    ...     ...      ...     ...    ...   ...   ...       ...
# 8799     806      0      69       GK     191   Left     0     0         0
# 8806    8247  Palop      77       GK     184  Right     0     0         0
# 8827    8910      0      63       GK     182  Right     1     0         0
# 8828     899      0      74       GK     194  Right     1     0         0
# 8839    9751      0      71       GK     196  Right     1     0         0
#
#       passing  dribbling  defending  heading  diving  handling  kicking  \
# ...

# %% [markdown]
# <span style="color:green">**As you can see that the dataframe is empty and no value has been assigned to it. Let's check out the issue.**</span>

# %% [markdown]
# **i. Check unique value of position, there must be a space on each position**

# %%
#Write code here

df['position'].unique()

#df.position.unique()
# Out:
# array(['GK', 'M', 'A', 'D'], dtype=object)

# %% [markdown]
# <span style="color:green">**From the above output, you can see that there is an extra space in the position reffered to as GK.**</span>

# %% [markdown]
# **ii. Remove extra space in position column and remove it like ' GK' to 'GK' and then again make dataframe of GK**<br>
# *Hint: Use str.replace*

# %%
#Write Code here

df['position'] = df['position'].str.replace(" ", "")

df['position'].unique()
# Out:
# array(['GK', 'M', 'A', 'D'], dtype=object)

# %% [markdown]
# **iii. Now make a dataframe of df_goalkeeper.**

# %%
#Write Your Code Here

df_goalkeeper= df[df['position'] == 'GK']
df_goalkeeper
# Out:
#           id   name  rating position  height   foot  rare  pace  shooting  \
# 0       1001      0      69       GK     191  Right     0     0         0
# 20    100745      0      64       GK     193  Right     1     0         0
# 29    100807      0      65       GK     190  Right     0     0         0
# 31    100899      0      61       GK     185  Right     1     0         0
# 39    101282      0      70       GK     188  Right     0     0         0
# ...      ...    ...     ...      ...     ...    ...   ...   ...       ...
# 8799     806      0      69       GK     191   Left     0     0         0
# 8806    8247  Palop      77       GK     184  Right     0     0         0
# 8827    8910      0      63       GK     182  Right     1     0         0
# 8828     899      0      74       GK     194  Right     1     0         0
# 8839    9751      0      71       GK     196  Right     1     0         0
#
#       passing  dribbling  defending  heading  diving  handling  kicking  \
# ...

# %% [markdown]
# **iv. Dataframe of goal keeper must and only contain the following columns 'id', 'name', 'rating', 'position', 'height', 'foot',' rare','diving', 'handling', 'kicking', 'reflexes', 'speed','positioning'** <br>
# **Drop all the other columns**

# %%
#write code here

df_goalkeeper = df_goalkeeper[[ 'id', 'name', 'rating', 'position', 'height', 'foot','rare', 'diving', 'handling', 'kicking', 'reflexes', 'speed','positioning']]
df_goalkeeper
# Out:
#           id   name  rating position  height   foot  rare  diving  handling  \
# 0       1001      0      69       GK     191  Right     0      70        66
# 20    100745      0      64       GK     193  Right     1      65        62
# 29    100807      0      65       GK     190  Right     0      62        68
# 31    100899      0      61       GK     185  Right     1      46        65
# 39    101282      0      70       GK     188  Right     0      72        64
# ...      ...    ...     ...      ...     ...    ...   ...     ...       ...
# 8799     806      0      69       GK     191   Left     0      71        73
# 8806    8247  Palop      77       GK     184  Right     0      78        79
# 8827    8910      0      63       GK     182  Right     1      60        66
# 8828     899      0      74       GK     194  Right     1      72        74
# 8839    9751      0      71       GK     196  Right     1      70        70
#
#       kicking  reflexes  speed  positioning
# ...

# %%
#cols = [7,8,9,10,11,12,13]
#df_goalkeeper.drop(df.columns[cols], axis=1)

# %%
#write code here

# %% [markdown]
# **v. Make the dataframe of df_players having data of the all the other players except the goal keeper.**

# %%
#Write Your Code Here
df_players= df[df['position'] != 'GK']
df_players
# Out:
#           id name  rating position  height   foot  rare  pace  shooting  \
# 1     100143    0      65        M     184  Right     0    61        65
# 2     100264    0      57        A     185  Right     0    65        54
# 3     100325    0      63        D     180   Left     0    68        38
# 4     100326    0      72        M     181  Right     0    75        64
# 5     100329    0      72        D     187  Right     1    50        37
# ...      ...  ...     ...      ...     ...    ...   ...   ...       ...
# 8842    9801    0      73        A     189   Left     1    62        73
# 8843    9805    0      79        A     175  Right     0    80        78
# 8844    9807    0      68        D     183  Right     0    61        40
# 8845    9815    0      65        D     179  Right     0    65        48
# 8846    9913    0      69        M     179  Right     0    55        56
#
#       passing  dribbling  defending  heading  diving  handling  kicking  \
# ...

# %% [markdown]
# **vi. Dataframe of other players must contain the following columns 'id', 'name', 'rating', 'position', 'height', 'foot', 'rare',  'pace', 'shooting', 'passing', 'dribbling', 'defending', 'heading'** <br>
# **Drop all the other columns**

# %%
#write code here

df_players=df_players[[ 'id', 'name', 'rating', 'position'  , 'height','foot', 'rare',  'pace', 'shooting', 'passing', 'dribbling', 'defending']]

df_players
# Out:
#           id name  rating position  height   foot  rare  pace  shooting  \
# 1     100143    0      65        M     184  Right     0    61        65
# 2     100264    0      57        A     185  Right     0    65        54
# 3     100325    0      63        D     180   Left     0    68        38
# 4     100326    0      72        M     181  Right     0    75        64
# 5     100329    0      72        D     187  Right     1    50        37
# ...      ...  ...     ...      ...     ...    ...   ...   ...       ...
# 8842    9801    0      73        A     189   Left     1    62        73
# 8843    9805    0      79        A     175  Right     0    80        78
# 8844    9807    0      68        D     183  Right     0    61        40
# 8845    9815    0      65        D     179  Right     0    65        48
# 8846    9913    0      69        M     179  Right     0    55        56
#
#       passing  dribbling  defending
# 1          63         59         62
# ...

# %%
#write code here

# %% [markdown]
# **vii. Find shape of both the datasets**

# %%
#Write Your Code Here
df_goalkeeper.shape
# Out:
# (930, 13)

# %%
#write code here
df_players.shape
# Out:
# (7917, 12)

# %% [markdown]
# **viii. Check head of both the splited dataframe**

# %%
#Write Your Code Here
df_goalkeeper.head()
# Out:
#         id name  rating position  height   foot  rare  diving  handling  \
# 0     1001    0      69       GK     191  Right     0      70        66
# 20  100745    0      64       GK     193  Right     1      65        62
# 29  100807    0      65       GK     190  Right     0      62        68
# 31  100899    0      61       GK     185  Right     1      46        65
# 39  101282    0      70       GK     188  Right     0      72        64
#
#     kicking  reflexes  speed  positioning
# 0        63        74     35           66
# 20       55        67     41           62
# 29       62        65     60           64
# 31       76        71     31           61
# 39       59        73     61           73

# %%
#Write Your Code Here
df_players.head()
# Out:
#        id name  rating position  height   foot  rare  pace  shooting  passing  \
# 1  100143    0      65        M     184  Right     0    61        65       63
# 2  100264    0      57        A     185  Right     0    65        54       43
# 3  100325    0      63        D     180   Left     0    68        38       51
# 4  100326    0      72        M     181  Right     0    75        64       67
# 5  100329    0      72        D     187  Right     1    50        37       47
#
#    dribbling  defending
# 1         59         62
# 2         53         55
# 3         46         64
# 4         72         57
# 5         43         76

# %% [markdown]
# **ix. Show the summary stats of both the datasets**

# %%
#Write Your Code Here for summary stats of goal keeper
df_goalkeeper.describe()
# Out:
#                   id     rating      height        rare      diving  \
# count     930.000000  930.00000  930.000000  930.000000  930.000000
# mean   144009.048387   65.91828  188.233333    0.345161   67.351613
# std     58295.056991    7.67349    4.701690    0.475677    8.311224
# min         6.000000   40.00000  173.000000    0.000000   30.000000
# 25%    134631.750000   61.00000  185.000000    0.000000   62.000000
# 50%    163614.500000   66.00000  188.000000    0.000000   67.000000
# 75%    186381.750000   71.00000  191.000000    1.000000   73.000000
# max    205409.000000   89.00000  208.000000    1.000000   91.000000
#
#          handling     kicking    reflexes       speed  positioning
# count  930.000000  930.000000  930.000000  930.000000   930.000000
# mean    64.739785   63.067742   68.865591   48.212903    64.955914
# std      8.073867    8.653150    8.546599   10.330171     8.854231
# min     39.000000   30.000000   32.000000   14.000000    37.000000
# ...

# %%
#Write Your Code Here for summary stats of players
df_players.describe()
# Out:
#                   id       rating       height         rare         pace  \
# count    7917.000000  7917.000000  7917.000000  7917.000000  7917.000000
# mean   153315.875205    66.769989   180.988885     0.354048    67.934066
# std     53963.758068     7.077355     6.200081     0.478254    11.169316
# min         2.000000    41.000000   158.000000     0.000000    24.000000
# 25%    141099.000000    62.000000   177.000000     0.000000    62.000000
# 50%    172252.000000    66.000000   181.000000     0.000000    69.000000
# 75%    189390.000000    72.000000   185.000000     1.000000    75.000000
# max    205583.000000    94.000000   203.000000     1.000000    96.000000
#
#           shooting      passing    dribbling    defending
# count  7917.000000  7917.000000  7917.000000  7917.000000
# mean     55.054440    58.845522    61.193887    60.339523
# std      13.136116    10.962049    12.255261    10.622997
# min      12.000000    13.000000    19.000000    26.000000
# ...

# %% [markdown]
# ### Question: What do you understand from the summary statistics of goal keeper?

# %% [markdown]
# ### Answer:
#
# 1. The average height of goalkeeper (188cm) which is more than the mean height of other players (180cm)
# 2. On the other hand, the average rating of a goalkeeper (65.9) is less than that of players playing in other positions i.e. 66.7.
# 3. Also, we can see the median rating for goalkeepers and players playing in other positions is the same i. e. 66.00

# %% [markdown]
# ### Question: What do you understanf from the summary statistics of other players?

# %% [markdown]
# ### Answer:
# 1. The average height of players playing in other positions is less than the average height of goalkeepers.
# 2. However, the players performing in other positions are better rated than goal keepers.
# 3. Lastly, we can observe that the median rating for players playing in other positions and goalkeepers is the same i. e. 66.00

# %% [markdown]
# ### Task 5: Group By and Pivoting

# %% [markdown]
# **i. Display averages of each columns according the players' positions**

# %%
#Write Your Code Here
df.groupby(['position']).mean()
# Out:
#                      id     rating      height      rare       pace  \
# position
# A         157071.437080  67.260807  180.938521  0.475024  72.488473
# D         150820.398712  66.059055  183.145669  0.270938  63.930923
# GK        144009.048387  65.918280  188.233333  0.345161   0.000000
# M         153037.440973  67.087142  179.041763  0.347583  68.493916
#
#            shooting    passing  dribbling  defending    heading     diving  \
# position
# A         63.759846  54.357349  66.664265  50.905860  64.756484   0.000000
# D         43.618110  55.465283  51.836793  68.069435  66.837867   0.000000
# GK         0.000000   0.000000   0.000000   0.000000   0.000000  67.351613
# M         59.601776  65.024005  66.045709  59.696153  60.206511   0.000000
#
#            handling    kicking   reflexes      speed  positioning
# position
# A          0.000000   0.000000   0.000000   0.000000     0.000000
# D          0.000000   0.000000   0.000000   0.000000     0.000000
# ...

# %% [markdown]
# **ii. Count number of players against each position and foot used by them.**
# *Hint: Use Groupby*

# %%
#Write Your Code Here
#Group By Here
df.groupby(['position','foot'])['id'].count().reset_index()
# Out:
#   position   foot    id
# 0        A   Left   368
# 1        A  Right  1714
# 2        D   Left   915
# 3        D  Right  1879
# 4       GK   Left    98
# 5       GK  Right   832
# 6        M   Left   704
# 7        M  Right  2337

# %% [markdown]
# **iii. Perform grouping on position and foot to find mean, min and max values of rating. Store the result in a variable called 'a'** <br>
# *Hint: Aggregate(mean,min,max) on rating using .agg() method and nested dictionaries* <br>

# %%
#Write Your Code Here

#Mean
df.groupby(['position','foot'])['rating'].mean().reset_index()
# Out:
#   position   foot     rating
# 0        A   Left  67.758152
# 1        A  Right  67.154026
# 2        D   Left  65.931148
# 3        D  Right  66.121341
# 4       GK   Left  68.102041
# 5       GK  Right  65.661058
# 6        M   Left  67.778409
# 7        M  Right  66.878905

# %%
#Min
df.groupby(['position','foot'])['rating'].min().reset_index()
# Out:
#   position   foot  rating
# 0        A   Left      51
# 1        A  Right      41
# 2        D   Left      47
# 3        D  Right      42
# 4       GK   Left      52
# 5       GK  Right      40
# 6        M   Left      43
# 7        M  Right      41

# %%
#Max
df.groupby(['position','foot'])['rating'].max().reset_index()
# Out:
#   position   foot  rating
# 0        A   Left      94
# 1        A  Right      92
# 2        D   Left      85
# 3        D  Right      89
# 4       GK   Left      89
# 5       GK  Right      86
# 6        M   Left      90
# 7        M  Right      92

# %% [markdown]
# **iv. Perform "PIVOTING" on the dataframe 'df'. The properties should be as following:**<br>
# *index = ' position'<br>
# columns = ' foot'<br>
# values=' rating'<br>
# aggfunc=['min','mean']*<br>

# %%
df.columns
# Out:
# Index(['id', 'name', 'rating', 'position', 'height', 'foot', 'rare', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'heading', 'diving',
#        'handling', 'kicking', 'reflexes', 'speed', 'positioning'],
#       dtype='object')

# %%
#Write Code Here
df.pivot_table(index='position', columns='foot', values='rating', aggfunc=['mean', 'min', 'max', 'median'])
# Out:
#                mean             min        max       median
# foot           Left      Right Left Right Left Right   Left Right
# position
# A         67.758152  67.154026   51    41   94    92   67.0  67.0
# D         65.931148  66.121341   47    42   85    89   65.0  66.0
# GK        68.102041  65.661058   52    40   89    86   67.5  65.5
# M         67.778409  66.878905   43    41   90    92   67.0  67.0

# %% [markdown]
# # Visualization

# %% [markdown]
# ### Task 6: Display total players of each position.

# %%
plt.figure(figsize=(10, 10))


#write code here

df_total=df.groupby('position')['id'].count()

#df['position'].value_counts(dropna=True)
#df.groupby('position')['id'].nunique()

df_total.plot()

# %%
sns.set(rc={"figure.figsize":(20, 20)})

sns.catplot(x='position', data = df, kind="count", order=df['position'].value_counts().index)

# Title
plt.title ("Total Players in each position", fontsize=20)


#Labels
plt.xlabel("Position of the Player", fontsize = 10)
plt.ylabel("Count of Players", fontsize= 10)
plt.show()

# %% [markdown]
# ### **Question: What insights do you get from the above plot?**
#
# ### **Answer:**
#
# ####  The above visualization provides us with the total number of players in each position namely, M, D, A and GK in descending order. Most players are positioned as midfielders while the least number of players are playing as Goal Keepers.

# %% [markdown]
# ### Task 7:  Show the total number of players for each foot type.

# %%
#Write code here

df.groupby('foot')['id'].count()
#df.groupby('foot')['id'].nunique()
# Out:
# foot
# Left     2085
# Right    6762
# Name: id, dtype: int64

# %%
plt.figure(figsize=(10, 10))


df.groupby('foot')['id'].count().plot()

# %%
# Bar Plot

sns.catplot(x='foot', data = df, kind="count" )

# Title 
plt.title ("Total Players for each foot type", fontsize=18)


#Labels
plt.xlabel("Foot type of the player", fontsize = 10)
plt.ylabel("Count of Players", fontsize= 15)
plt.show()

# %% [markdown]
# ### Task 8. Show 'foot' ditribution per 'rating' using boxplot

# %%
#write code here
sns.boxplot(x='foot', y= 'rating', data=df)
plt.title('Box Plot for foot distribution per rating', fontsize=20)

plt.xlabel("Foot", fontsize = 12)
plt.ylabel("Ratings", fontsize= 12)
# Out:
# Text(0, 0.5, 'Ratings')

# %%
sns.catplot(x='foot', y ='rating', data = df, kind="box", whis = [0,100])

plt.title ("Foot Distribution per Rating", fontsize=20)
plt.xlabel("Foot", fontsize = 12)
plt.ylabel("Ratings", fontsize= 12)
# Out:
# Text(12.334999999999994, 0.5, 'Ratings')

# %% [markdown]
# **Question: What does the above box plot show?**
#
# **ANSWER:**
# The above plot compare the Foot Distribution per Rating for right foot and left foot. There are outliers outside the inter-quartile range for both left and right foot.
#
# 1. The median of right foot rating is a little less the median of left foot rating.
#
# 2. The measure of min value of rating for right foot is less than the min value of rating for left foot.
#
# 3. The measure of max value of rating for right foot is less than the max value of rating for left foot.

# %% [markdown]
# ### Task 9. Display total number of players for each foot type according to their positions. But the result of each position should be a separate graph yet shown collectively  <br>
# *Hint: You can use subplots and you can have a separate dataframe for each postion. Sample code fir subplots is given below:*<br>
# *Sample Code
# <br>*
# ```
# fig, ax=plt.subplots(2,2,sharey=True, figsize=(15,8))
# sns.countplot(x='rating', data=df_goalkeeper, ax=ax[0,0])
# ax[0,0].set_title('Goal keeper')
# ```

# %%
df['position'].unique()
# Out:
# array(['GK', 'M', 'A', 'D'], dtype=object)

# %%
# Creating separate DataFrames to subset each position

df_gk= df[df['position'] == "GK"]
df_mid= df[df['position'] == "M"]
df_attack= df[df['position'] == "A"]
df_def= df[df['position'] == "D"]

# %%
#Write code here
fig, ax=plt.subplots(2,2,sharey=True, figsize=(15,15))
fig.suptitle('Total  Players for each foot type according to their  position', fontsize=25)

sns.countplot(x='foot', data=df_gk, ax=ax[0,0])
ax[0,0].set_title('Goal keeper')


sns.countplot(x='foot', data=df_attack, ax=ax[0,1])
ax[0,1].set_title('Attacker')


sns.countplot(x='foot', data=df_mid, ax=ax[1,0])
ax[1,0].set_title('Midfielder')


sns.countplot(x='foot', data=df_def, ax=ax[1,1])
ax[1,1].set_title('Defender')
# Out:
# Text(0.5, 1.0, 'Defender')

# %% [markdown]
# ### Task 10: What can be the relationship/correlation  ratings and defending of other players.<br>
# *Hint: reg plot*

# %%
df['rating'].corr(df['defending'])
# Out:
# 0.20512264575553535

# %%
plt.figure(figsize=(8,8))

sns.regplot(x='defending',y = 'rating',data = df_players)

plt.title("Correlation between Rating and Defence of player", fontsize=20)
plt.xlabel("Defence", fontsize=15)
plt.ylabel("Rating", fontsize=15)
# Out:
# Text(0, 0.5, 'Rating')

# %% [markdown]
# **Question: What does the above plot show?**
#
# **Answer: The above plot shows that a positive correlation exist between Defence and Rating of other players. However, the positive correlation is not very high.**

# %% [markdown]
# ### Task 11: Plot a graph to show the relationship/correlation among rating and handling of goal keeper. Also the distributions of each should be displayed along with the graph showing the relationship.<br>
# *Hint: jointplot*

# %%
#Write code here
df['rating'].corr(df_goalkeeper['handling'])
# Out:
# 0.8966271112403557

# %%
#Write code here

plt.figure(figsize=(10, 20))

sns.jointplot(data=df_gk, x="handling", y="rating")

# %% [markdown]
# ### Task 12-a.  Make a heatmap to show correlation among all the columns of the goal keeper dataframe and answer the questions

# %%
#write code here to find the correlation
df_goalkeeper.corr()
# Out:
#                    id    rating    height      rare    diving  handling  \
# id           1.000000 -0.355814  0.000388 -0.135258 -0.257888 -0.349666
# rating      -0.355814  1.000000  0.099763  0.231273  0.920651  0.896627
# height       0.000388  0.099763  1.000000  0.046735  0.091859  0.112361
# rare        -0.135258  0.231273  0.046735  1.000000  0.195529  0.230818
# diving      -0.257888  0.920651  0.091859  0.195529  1.000000  0.742630
# handling    -0.349666  0.896627  0.112361  0.230818  0.742630  1.000000
# kicking     -0.264304  0.702664  0.086684  0.262367  0.619452  0.675943
# reflexes    -0.232939  0.893557  0.056339  0.216361  0.858516  0.697350
# speed        0.003586  0.214803 -0.021480  0.004306  0.235284  0.142400
# positioning -0.418950  0.900010  0.084102  0.199900  0.740798  0.845211
#
#               kicking  reflexes     speed  positioning
# id          -0.264304 -0.232939  0.003586    -0.418950
# rating       0.702664  0.893557  0.214803     0.900010
# ...

# %%
#write code here for heatmap

plt.figure(figsize=(15,8))
sns.heatmap(df_goalkeeper.corr(), annot= True)

plt.title("Correlation among all the columns of the goal keeper dataframe", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation among all the columns of the goal keeper dataframe')

# %% [markdown]
# **Question: Which columns/variables/factors are important to determine ratings of goal keepers and why?**
#
# Answer: The following columns/variables/factors are important to determine rating of goal keepers since they are strongly and positively correlated:
# 1. Diving (0.92)
# 2. Handling (0.9)
# 3. Positioning (0.9)
# 4. Reflexes (0.89)

# %% [markdown]
# ### Task 12-b. Make a heatmap show correlation among all the columns of dataframe having data of all the other players and answer the questions

# %%
# Write the code to find the correlation here
df_players.corr()
# Out:
#                  id    rating    height      rare      pace  shooting  \
# id         1.000000 -0.254920 -0.016548 -0.040907  0.253182 -0.128368
# rating    -0.254920  1.000000 -0.002019  0.251950  0.265640  0.541683
# height    -0.016548 -0.002019  1.000000 -0.023979 -0.392051 -0.219175
# rare      -0.040907  0.251950 -0.023979  1.000000  0.276355  0.244903
# pace       0.253182  0.265640 -0.392051  0.276355  1.000000  0.360584
# shooting  -0.128368  0.541683 -0.219175  0.244903  0.360584  1.000000
# passing   -0.177869  0.633406 -0.273012  0.126480  0.260352  0.558012
# dribbling -0.032934  0.539971 -0.401063  0.227765  0.573711  0.783148
# defending -0.221930  0.387013  0.356490 -0.057604 -0.291526 -0.239953
#
#             passing  dribbling  defending
# id        -0.177869  -0.032934  -0.221930
# rating     0.633406   0.539971   0.387013
# height    -0.273012  -0.401063   0.356490
# rare       0.126480   0.227765  -0.057604
# pace       0.260352   0.573711  -0.291526
# ...

# %%
#write code here for heatmap
plt.figure(figsize=(15,8))
sns.heatmap(df_players.corr(), annot= True)

plt.title("Correlation among all the columns of the other players dataframe", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation among all the columns of the other players dataframe')

# %% [markdown]
# **Question: Which columns/variables/factors are important to dertmine ratings of other players and why?**
#
# Answer: The following columns/variables/factors  determine rating of other players since they are positively correlated moderately:
# 1. Passing (0.63)
# 2. Shooting (0.54)
# 3. Dribbling (0.54)
# 4. Defendng (0.39)

# %% [markdown]
# ### Task 13. Show distribution of rating.
# *Hint: Use dist plot*

# %%
#write code here

plt.figure(figsize=(15,8))

sns.distplot(df['rating'], kde=True, bins=15 ,  hist_kws={'linewidth':0.5, 'linestyle':'--', 'alpha':0.7}, kde_kws={'color':'green'})

plt.title("Distribution of Rating", fontsize=20)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of Rating')

# %% [markdown]
# **Question: What insights do you get from the distplot drawn above?**

# %% [markdown]
# ### Task 14: Show the distribution of ratings of each types of players through KDE plot using distplot() function

# %%
#Write code here


fig, ax=plt.subplots(2,2,sharey=True, figsize=(20,15))


sns.kdeplot(df_attack['rating'], ax=ax[0,0]).set(title="Attack Players")

sns.kdeplot(df_mid['rating'], ax=ax[0,1]).set(title="Midfield Players")


#subplot(2,2,3)
sns.kdeplot(df_def['rating'], ax=ax[1,0]).set(title="Defence Players")


#subplot(2,2,4)
sns.kdeplot(df_gk['rating'],ax=ax[1,1]).set(title="Goal Keeper")
# Out:
# [Text(0.5, 1.0, 'Goal Keeper')]

# %% [markdown]
# ### Task 15: What is the count of rare players in each type of postion?

# %%
#write code here

df.groupby('position')['rare'].sum().reset_index(name='count')
# Out:
#   position  count
# 0        A    989
# 1        D    757
# 2       GK    321
# 3        M   1057

# %%
df['rare'].sum()
# Out:
# 3124
